# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.2.0

# %% [markdown]
# ## Encoder Function

# %%
encoder_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10),input_shape=(256,256,3)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.MaxPooling2D((2,2),padding='same'),
    tf.keras.layers.Conv2D()

    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.MaxPooling2D((2,2),padding='same'),

    tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))

])
# Out:
#   File "<ipython-input-3-e6487ae9b6f3>", line 7
#     tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
#      ^
# SyntaxError: invalid syntax

# %%
encoder_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 64, 64, 256)       295168
# =================================================================
# Total params: 555,328
# Trainable params: 555,328
# Non-trainable params: 0
# _________________________________________________________________

# %%
'''
##Evabeo Model ta banano jay Bro!!
input_img = tf.keras.layers.Input(shape=(256,256,3))
l = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(input_img)
l = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)
l = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l)

l = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)
l = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)
l = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l)

last_layer = tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)

e_model = tf.keras.Model(input_img,last_layer)

e_model.summary()
'''
# Out:
# "\n##Evabeo Model ta banano jay Bro!!\ninput_img = tf.keras.layers.Input(shape=(256,256,3))\nl = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(input_img)\nl = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)\nl = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l)\n\nl = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)\nl = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)\nl = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l)\n\nlast_layer = tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l)\n\ne_model = tf.keras.Model(input_img,last_layer)\n\ne_model.summary()\n"

# %% [markdown]
# ## Auto Encoder Function (Encoder+Decoder)

# %%
"""
autoencoder_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10),input_shape=(256,256,3)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.MaxPooling2D((2,2),padding='same'),

    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.MaxPooling2D((2,2),padding='same'),

    tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),

    ##Etotuk Encoder ...erpor decoder er part

    tf.keras.layers.UpSampling2D(),
    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),

    tf.keras.layers.add([get_layer('conv2d_3').output,get_layer('conv2d_6').output]),

    tf.keras.layers.UpSampling2D(),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),
    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),

    tf.keras.layers.add([get_layer('conv2d_1').output,get_layer('conv2d_8').output]),


    tf.keras.layers.Conv2D(3,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))
])
"""
# Out:
# "\nautoencoder_model = tf.keras.models.Sequential([\n    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10),input_shape=(256,256,3)),\n    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n    tf.keras.layers.MaxPooling2D((2,2),padding='same'),\n\n    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n    tf.keras.layers.MaxPooling2D((2,2),padding='same'),\n\n    tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n\n    ##Etotuk Encoder ...erpor decoder er part\n\n    tf.keras.layers.UpSampling2D(),\n    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n    tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n\n    tf.keras.layers.add([get_layer('conv2d_3').output,get_layer('conv2d_6').output]),\n\n    tf.keras.layers.UpSampling2D(),\n    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n    tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10)),\n\n    tf.keras.layers.add([get_layer('conv2d_1').output,get_layer('conv2d_8').output]),\n\n\n    tf.keras.layers.Conv2D(3,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))\n])\n"

# %%
target_height = 300
target_width = 300


input_img = tf.keras.layers.Input(shape=(target_height,target_width,3))
l1 = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(input_img)
l2 = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l1)
l3 = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l2)

l4 = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l3)
l5 = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l4)
l6 = tf.keras.layers.MaxPooling2D((2,2),padding='same')(l5)

encoded_output =  tf.keras.layers.Conv2D( 256, (3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l6)

##Etotuk Encoder ...erpor decoder er part

l8 =  tf.keras.layers.UpSampling2D()(encoded_output)
l9 =  tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l8)
l10 = tf.keras.layers.Conv2D(128,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l9)

l11 = tf.keras.layers.add([l5,l10])

l12 = tf.keras.layers.UpSampling2D()(l11)
l13 = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l12)
l14 = tf.keras.layers.Conv2D(64,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l13)

l15 = tf.keras.layers.add([l2,l14])


decoded_output = tf.keras.layers.Conv2D(3,(3,3),padding='same',activation='relu',activity_regularizer=tf.keras.regularizers.l1(1e-10))(l15)


autoencoder = tf.keras.models.Model(inputs = input_img,outputs = decoded_output)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 300, 300, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 300, 300, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 150, 150, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 150, 150, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 150, 150, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 150, 150, 256 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 150, 150, 128 295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 150, 150, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 150, 128 0           conv2d_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 300, 300, 128 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 300, 300, 64) 73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 300, 300, 64) 36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 300, 300, 64) 0           conv2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 300, 300, 3)  1731        add_1[0][0]
# ==================================================================================================
# Total params: 1,110,403
# Trainable params: 1,110,403
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.models import Model

vgg_model = VGG19(include_top = False, weights = 'imagenet')
vgg_model.trainable = False

vgg_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, None, None, 3)]   0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, None, None, 64)    1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, None, None, 64)    36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, None, None, 64)    0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, None, None, 128)   73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, None, None, 128)   147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, None, None, 128)   0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, None, None, 256)   295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, None, None, 256)   590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, None, None, 256)   0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, None, None, 512)   1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, None, None, 512)   0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, None, None, 512)   2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, None, None, 512)   0
# =================================================================
# Total params: 20,024,384
# Trainable params: 0
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
selected_layers = ['block2_conv2',
                   'block3_conv3',
                   'block4_conv3',
                   'block5_conv3']

# %%
selected_outputs = [ vgg_model.get_layer(layer).output for layer in selected_layers ]
vgg_model = Model(vgg_model.inputs, selected_outputs )

# %%
vgg_model_outputs = vgg_model(decoded_output)

full_model = Model(autoencoder.input,vgg_model_outputs)
full_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 300, 300, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 300, 300, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 300, 300, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 150, 150, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 150, 150, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 150, 150, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 75, 75, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 75, 75, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 150, 150, 256 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 150, 150, 128 295040      up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 150, 150, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 150, 150, 128 0           conv2d_3[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 300, 300, 128 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 300, 300, 64) 73792       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 300, 300, 64) 36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 300, 300, 64) 0           conv2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 300, 300, 3)  1731        add_1[0][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 multiple             17664576    conv2d_9[0][0]
# ==================================================================================================
# Total params: 18,774,979
# Trainable params: 1,110,403
# Non-trainable params: 17,664,576
# __________________________________________________________________________________________________

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd 'drive/My Drive/All Project Works/My Fancy Project/Image High Resolution'
# Out:
# /content/drive/My Drive/All Project Works/My Fancy Project/Image High Resolution

# %%
ls
# Out:
#  autoencoder_model.json                           logs/
#  autoencoder_model_weights_0.h5                   low_res_car_0.3/
#  autoencoder_model_weights_1.h5                   low_res_car_0.5/
#  cars/                                            Version_1/
#  Golu.jpg                                        'Version_2 with perp loss'/
# 'Image High Resolution using AutoEncoder.ipynb'

# %%
full_model.compile(loss='mse', optimizer='adam',metrics=['accuracy'])

# %%
import os
import re
import numpy as np
from scipy import ndimage, misc
from skimage.transform import resize, rescale
import skimage

import matplotlib.pyplot as plt
from PIL import Image
from tensorflow.keras.preprocessing.image import load_img

# %%
def rescaling_images(img,scaling_factor=0.5):

  image = np.array(img)

  im_r = image[:,:,0]
  im_g = image[:,:,1]
  im_b = image[:,:,2]

  for i in range(3):
      im_scaled_r = np.expand_dims(rescale(im_r,scaling_factor),axis=2)
      im_scaled_g = np.expand_dims(rescale(im_g,scaling_factor),axis=2)
      im_scaled_b = np.expand_dims(rescale(im_b,scaling_factor),axis=2)
      
  image_rescaled=np.concatenate((im_scaled_r,im_scaled_g,im_scaled_b),axis=2)

  return image_rescaled

# %%
high_res_img_path = os.getcwd()+'/cars'
low_res_img_path = os.getcwd()+'/low_res_car_0.3'

all_images_name = os.listdir(high_res_img_path)

index = int(np.random.randint(low=0,high=len(all_images_name)-1, size=1))

img_path = low_res_img_path + '/' + all_images_name[index]
test_image = plt.imread(img_path)

img_path = high_res_img_path + '/' + all_images_name[index]
actual_image = plt.imread(img_path)

plt.figure(figsize = (100,100))

plt.subplot(10,10,1)
plt.imshow(test_image)

plt.subplot(10,10,2)
plt.imshow(actual_image)

print(test_image)
print(test_image.shape)
# Out:
# [[[ 91  96  74]
#   [ 90  95  73]
#   [ 87  92  70]
#   ...
#   [156 178 157]
#   [109 131 110]
#   [ 62  84  63]]
#
#  [[ 50  58  35]
#   [ 46  54  31]
#   [ 44  53  32]
#   ...
#   [147 169 148]
#   [ 90 112  91]
#   [ 35  57  36]]
#
#  [[ 32  46  21]
#   [ 24  38  15]
#   [ 24  37  17]
#   ...
#   [ 39  60  41]
#   [ 24  45  26]
#   [ 33  54  35]]
#
#  ...
#
#  [[195 196 200]
#   [189 190 194]
#   [197 198 200]
#   ...
#   [214 214 212]
#   [213 213 211]
#   [214 214 212]]
#
#  [[199 200 204]
#   [192 193 197]
#   [199 200 202]
#   ...
#   [213 213 211]
#   [211 211 209]
#   [210 210 208]]
#
#  [[201 202 206]
#   [193 194 198]
#   [199 200 202]
#   ...
#   [209 209 207]
#   [206 206 204]
#   [205 205 203]]]
# (108, 144, 3)

# %%
## A Function that downscales image by factor of 3 and saves
## No need to save low res image in directory if not necessery
'''

filenames = os.listdir(os.getcwd()+'/cars')
count = 1
number_of_files = len(filenames)

for img in filenames:
  print("{}/{} files are done".format(count,number_of_files))
  count = count+1
  image = load_img(os.getcwd()+'/cars/'+img)
  rescaled_img = rescaling_images(image,0.3)
  rescaled_img = (rescaled_img*255).astype('uint8')
  rescaled_img = Image.fromarray(rescaled_img)
  rescaled_img.save(os.getcwd()+"/low_res_car/" + img)

'''
# Out:
# '\n\nfilenames = os.listdir(os.getcwd()+\'/cars\')\ncount = 1\nnumber_of_files = len(filenames)\n\nfor img in filenames:\n  print("{}/{} files are done".format(count,number_of_files))\n  count = count+1\n  image = load_img(os.getcwd()+\'/cars/\'+img)\n  rescaled_img = rescaling_images(image,0.3)\n  rescaled_img = (rescaled_img*255).astype(\'uint8\')\n  rescaled_img = Image.fromarray(rescaled_img)\n  rescaled_img.save(os.getcwd()+"/low_res_car/" + img)\n\n'

# %%
  ##This process recquires huge RAM...better to divide the dataset into batches

"""
def train_batches():

  number_of_epochs=4
  images = []
  low_res_img = []
  high_res_img = []

  low_res_img_arr = []
  high_res_img_arr = []

  train_path = os.getcwd()+'/cars_train'

  images_name = os.listdir(train_path)
  images_name = images_name[:1200]

  for filename in images_name:

    filepath = os.path.join(train_path,filename)

    img = plt.imread(filepath)
    low_res = rescaling_images(img) #sent original image for rescaling and saved it in low_res

    img = skimage.transform.resize(img,(target_height,target_width))
    high_res_img.append(img)


    low_res = skimage.transform.resize(low_res,(target_height,target_width))
    low_res_img.append(low_res)

    low_res_img_arr = np.array(low_res_img)
    high_res_img_arr = np.array(high_res_img)


  autoencoder.fit(low_res_img_arr,high_res_img_arr,epochs=number_of_epochs,batch_size=10,shuffle=True)
  """
# Out:
# "\ndef train_batches():\n\nnumber_of_epochs=4\nimages = []\nlow_res_img = []\nhigh_res_img = []\n\nlow_res_img_arr = []\nhigh_res_img_arr = []\n\ntrain_path = os.getcwd()+'/cars_train'\n\nimages_name = os.listdir(train_path)\nimages_name = images_name[:1200]\n\nfor filename in images_name:\n\n  filepath = os.path.join(train_path,filename)\n\n  img = plt.imread(filepath)\n  low_res = rescaling_images(img) #sent original image for rescaling and saved it in low_res\n\n  img = skimage.transform.resize(img,(target_height,target_width))\n  high_res_img.append(img)\n\n\n  low_res = skimage.transform.resize(low_res,(target_height,target_width))\n  low_res_img.append(low_res)\n\n  low_res_img_arr = np.array(low_res_img)\n  high_res_img_arr = np.array(high_res_img)\n\n\nautoencoder.fit(low_res_img_arr,high_res_img_arr,epochs=number_of_epochs,batch_size=10,shuffle=True)\n"

# %%
from keras.models import model_from_json


def saving_model(epo, model_save=True):

  if model_save:
    autoencoder_model_json = autoencoder.to_json()
    with open("autoencoder_model.json", "w") as json_file:
        json_file.write(autoencoder_model_json)

    autoencoder.save_weights("autoencoder_model_weights_" +str(epo)+".h5")

    print("Saved model to disk")
# Out:
# Using TensorFlow backend.

# %%
def train_batches(number_of_epochs=5, no_of_images_in_single_batch = 16):


  mini_batch_no = int(len(all_images_name)/no_of_images_in_single_batch)

  for epo in range(number_of_epochs):
    print("===============================Epoch No: {}/{}==================================\n\n".format(epo+1,number_of_epochs))

    for mini_batch in range(mini_batch_no):
      print("\n--------------------Mini Batch No. {}/{}-------------------\n".format(mini_batch+1,mini_batch_no))

      low_res_img_arr = []
      high_res_img_arr = []

      images_name = all_images_name[mini_batch*no_of_images_in_single_batch: (mini_batch+1)*no_of_images_in_single_batch]

      for img_name in images_name:
        
        low_img_path = os.path.join(low_res_img_path,img_name)
        high_img_path = os.path.join(high_res_img_path,img_name)

        low_res_img = plt.imread(low_img_path)
        high_res_img = plt.imread(high_img_path)


        if len(high_res_img.shape)>2:
          low_res_img = skimage.transform.resize(low_res_img,(target_height,target_width))
          high_res_img = skimage.transform.resize(high_res_img,(target_height,target_width))

          low_res_img_arr.append(low_res_img)
          high_res_img_arr.append(high_res_img)

      low_res_img_arr = np.array(low_res_img_arr)
      high_res_img_arr = np.array(high_res_img_arr)

      full_model.fit( x = low_res_img_arr,y = vgg_model(high_res_img_arr),epochs=5,shuffle=True)

    saving_model(epo,model_save=True)

# %%
train_batches(number_of_epochs=1, no_of_images_in_single_batch=4)
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4015 - model_1_loss: 0.8223 - model_1_1_loss: 2.3753 - model_1_2_loss: 4.1823 - model_1_3_loss: 0.0214 - model_1_accuracy: 0.8225 - model_1_1_accuracy: 0.7542 - model_1_2_accuracy: 0.7337 - model_1_3_accuracy: 0.7307
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3483 - model_1_loss: 0.8121 - model_1_1_loss: 2.3608 - model_1_2_loss: 4.1538 - model_1_3_loss: 0.0216 - model_1_accuracy: 0.8237 - model_1_1_accuracy: 0.7538 - model_1_2_accuracy: 0.7348 - model_1_3_accuracy: 0.7299
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3100 - model_1_loss: 0.8046 - model_1_1_loss: 2.3458 - model_1_2_loss: 4.1378 - model_1_3_loss: 0.0217 - model_1_accuracy: 0.8243 - model_1_1_accuracy: 0.7562 - model_1_2_accuracy: 0.7358 - model_1_3_accuracy: 0.7299
#
# --------------------Mini Batch No. 1462/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 14.1124 - model_1_loss: 1.4214 - model_1_1_loss: 4.2578 - model_1_2_loss: 8.3878 - model_1_3_loss: 0.0454 - model_1_accuracy: 0.7390 - model_1_1_accuracy: 0.6399 - model_1_2_accuracy: 0.5970 - model_1_3_accuracy: 0.5965
# Epoch 2/5
# 1/1 [==============================] - 0s 4ms/step - loss: 13.9442 - model_1_loss: 1.4228 - model_1_1_loss: 4.2207 - model_1_2_loss: 8.2564 - model_1_3_loss: 0.0443 - model_1_accuracy: 0.7391 - model_1_1_accuracy: 0.6424 - model_1_2_accuracy: 0.6015 - model_1_3_accuracy: 0.6011
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 13.7168 - model_1_loss: 1.4295 - model_1_1_loss: 4.1743 - model_1_2_loss: 8.0702 - model_1_3_loss: 0.0427 - model_1_accuracy: 0.7389 - model_1_1_accuracy: 0.6437 - model_1_2_accuracy: 0.6079 - model_1_3_accuracy: 0.6073
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.5146 - model_1_loss: 1.4361 - model_1_1_loss: 4.1319 - model_1_2_loss: 7.9052 - model_1_3_loss: 0.0413 - model_1_accuracy: 0.7382 - model_1_1_accuracy: 0.6455 - model_1_2_accuracy: 0.6103 - model_1_3_accuracy: 0.6142
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.3300 - model_1_loss: 1.4403 - model_1_1_loss: 4.0905 - model_1_2_loss: 7.7590 - model_1_3_loss: 0.0401 - model_1_accuracy: 0.7382 - model_1_1_accuracy: 0.6458 - model_1_2_accuracy: 0.6150 - model_1_3_accuracy: 0.6111
#
# --------------------Mini Batch No. 1463/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1571 - model_1_loss: 0.8001 - model_1_1_loss: 2.1989 - model_1_2_loss: 4.1375 - model_1_3_loss: 0.0206 - model_1_accuracy: 0.8249 - model_1_1_accuracy: 0.7695 - model_1_2_accuracy: 0.7303 - model_1_3_accuracy: 0.7593
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0543 - model_1_loss: 0.7940 - model_1_1_loss: 2.1743 - model_1_2_loss: 4.0658 - model_1_3_loss: 0.0200 - model_1_accuracy: 0.8258 - model_1_1_accuracy: 0.7699 - model_1_2_accuracy: 0.7332 - model_1_3_accuracy: 0.7600
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9018 - model_1_loss: 0.7847 - model_1_1_loss: 2.1339 - model_1_2_loss: 3.9637 - model_1_3_loss: 0.0194 - model_1_accuracy: 0.8279 - model_1_1_accuracy: 0.7712 - model_1_2_accuracy: 0.7372 - model_1_3_accuracy: 0.7600
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.7534 - model_1_loss: 0.7760 - model_1_1_loss: 2.0950 - model_1_2_loss: 3.8635 - model_1_3_loss: 0.0188 - model_1_accuracy: 0.8305 - model_1_1_accuracy: 0.7733 - model_1_2_accuracy: 0.7348 - model_1_3_accuracy: 0.7600
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.6012 - model_1_loss: 0.7663 - model_1_1_loss: 2.0563 - model_1_2_loss: 3.7604 - model_1_3_loss: 0.0182 - model_1_accuracy: 0.8331 - model_1_1_accuracy: 0.7785 - model_1_2_accuracy: 0.7416 - model_1_3_accuracy: 0.7631
#
# --------------------Mini Batch No. 1464/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.5172 - model_1_loss: 1.3309 - model_1_1_loss: 3.8225 - model_1_2_loss: 7.3282 - model_1_3_loss: 0.0355 - model_1_accuracy: 0.7831 - model_1_1_accuracy: 0.7014 - model_1_2_accuracy: 0.6408 - model_1_3_accuracy: 0.6605
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1418 - model_1_loss: 1.2906 - model_1_1_loss: 3.7114 - model_1_2_loss: 7.1047 - model_1_3_loss: 0.0349 - model_1_accuracy: 0.7875 - model_1_1_accuracy: 0.7050 - model_1_2_accuracy: 0.6512 - model_1_3_accuracy: 0.6728
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.8090 - model_1_loss: 1.2492 - model_1_1_loss: 3.6123 - model_1_2_loss: 6.9125 - model_1_3_loss: 0.0349 - model_1_accuracy: 0.7925 - model_1_1_accuracy: 0.7069 - model_1_2_accuracy: 0.6644 - model_1_3_accuracy: 0.6752
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5372 - model_1_loss: 1.2165 - model_1_1_loss: 3.5351 - model_1_2_loss: 6.7503 - model_1_3_loss: 0.0351 - model_1_accuracy: 0.7963 - model_1_1_accuracy: 0.7122 - model_1_2_accuracy: 0.6738 - model_1_3_accuracy: 0.6759
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.2949 - model_1_loss: 1.1957 - model_1_1_loss: 3.4701 - model_1_2_loss: 6.5940 - model_1_3_loss: 0.0350 - model_1_accuracy: 0.7990 - model_1_1_accuracy: 0.7159 - model_1_2_accuracy: 0.6749 - model_1_3_accuracy: 0.6759
#
# --------------------Mini Batch No. 1465/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.3432 - model_1_loss: 1.0171 - model_1_1_loss: 4.0239 - model_1_2_loss: 7.2721 - model_1_3_loss: 0.0300 - model_1_accuracy: 0.8203 - model_1_1_accuracy: 0.6772 - model_1_2_accuracy: 0.6596 - model_1_3_accuracy: 0.6520
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1635 - model_1_loss: 1.0186 - model_1_1_loss: 3.9705 - model_1_2_loss: 7.1445 - model_1_3_loss: 0.0298 - model_1_accuracy: 0.8197 - model_1_1_accuracy: 0.6748 - model_1_2_accuracy: 0.6543 - model_1_3_accuracy: 0.6520
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.7419 - model_1_loss: 1.0231 - model_1_1_loss: 3.8411 - model_1_2_loss: 6.8485 - model_1_3_loss: 0.0291 - model_1_accuracy: 0.8178 - model_1_1_accuracy: 0.6754 - model_1_2_accuracy: 0.6561 - model_1_3_accuracy: 0.6489
# Epoch 4/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.3379 - model_1_loss: 1.0378 - model_1_1_loss: 3.7254 - model_1_2_loss: 6.5465 - model_1_3_loss: 0.0281 - model_1_accuracy: 0.8156 - model_1_1_accuracy: 0.6792 - model_1_2_accuracy: 0.6589 - model_1_3_accuracy: 0.6566
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.0473 - model_1_loss: 1.0604 - model_1_1_loss: 3.6417 - model_1_2_loss: 6.3177 - model_1_3_loss: 0.0274 - model_1_accuracy: 0.8127 - model_1_1_accuracy: 0.6803 - model_1_2_accuracy: 0.6633 - model_1_3_accuracy: 0.6566
#
# --------------------Mini Batch No. 1466/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.1519 - model_1_loss: 0.8234 - model_1_1_loss: 2.5637 - model_1_2_loss: 4.7432 - model_1_3_loss: 0.0215 - model_1_accuracy: 0.7750 - model_1_1_accuracy: 0.6725 - model_1_2_accuracy: 0.6810 - model_1_3_accuracy: 0.6782
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.0011 - model_1_loss: 0.8214 - model_1_1_loss: 2.5235 - model_1_2_loss: 4.6353 - model_1_3_loss: 0.0209 - model_1_accuracy: 0.7751 - model_1_1_accuracy: 0.6748 - model_1_2_accuracy: 0.6881 - model_1_3_accuracy: 0.6875
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8059 - model_1_loss: 0.8152 - model_1_1_loss: 2.4748 - model_1_2_loss: 4.4958 - model_1_3_loss: 0.0200 - model_1_accuracy: 0.7744 - model_1_1_accuracy: 0.6788 - model_1_2_accuracy: 0.6945 - model_1_3_accuracy: 0.6906
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6294 - model_1_loss: 0.8088 - model_1_1_loss: 2.4363 - model_1_2_loss: 4.3651 - model_1_3_loss: 0.0192 - model_1_accuracy: 0.7753 - model_1_1_accuracy: 0.6758 - model_1_2_accuracy: 0.7016 - model_1_3_accuracy: 0.6921
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4215 - model_1_loss: 0.7947 - model_1_1_loss: 2.3811 - model_1_2_loss: 4.2272 - model_1_3_loss: 0.0185 - model_1_accuracy: 0.7780 - model_1_1_accuracy: 0.6788 - model_1_2_accuracy: 0.7073 - model_1_3_accuracy: 0.6960
#
# --------------------Mini Batch No. 1467/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9303 - model_1_loss: 0.4849 - model_1_1_loss: 1.5359 - model_1_2_loss: 2.8949 - model_1_3_loss: 0.0144 - model_1_accuracy: 0.8426 - model_1_1_accuracy: 0.7488 - model_1_2_accuracy: 0.7765 - model_1_3_accuracy: 0.7531
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6903 - model_1_loss: 0.4642 - model_1_1_loss: 1.4605 - model_1_2_loss: 2.7519 - model_1_3_loss: 0.0136 - model_1_accuracy: 0.8485 - model_1_1_accuracy: 0.7563 - model_1_2_accuracy: 0.7860 - model_1_3_accuracy: 0.7585
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5211 - model_1_loss: 0.4453 - model_1_1_loss: 1.4106 - model_1_2_loss: 2.6521 - model_1_3_loss: 0.0130 - model_1_accuracy: 0.8534 - model_1_1_accuracy: 0.7602 - model_1_2_accuracy: 0.7894 - model_1_3_accuracy: 0.7677
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4979 - model_1_loss: 0.4382 - model_1_1_loss: 1.4058 - model_1_2_loss: 2.6410 - model_1_3_loss: 0.0128 - model_1_accuracy: 0.8573 - model_1_1_accuracy: 0.7615 - model_1_2_accuracy: 0.7927 - model_1_3_accuracy: 0.7785
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4699 - model_1_loss: 0.4348 - model_1_1_loss: 1.3939 - model_1_2_loss: 2.6284 - model_1_3_loss: 0.0127 - model_1_accuracy: 0.8582 - model_1_1_accuracy: 0.7628 - model_1_2_accuracy: 0.7969 - model_1_3_accuracy: 0.7762
#
# --------------------Mini Batch No. 1468/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.9257 - model_1_loss: 1.2357 - model_1_1_loss: 3.7961 - model_1_2_loss: 6.8497 - model_1_3_loss: 0.0441 - model_1_accuracy: 0.7861 - model_1_1_accuracy: 0.7130 - model_1_2_accuracy: 0.6711 - model_1_3_accuracy: 0.6389
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.7220 - model_1_loss: 1.2384 - model_1_1_loss: 3.7625 - model_1_2_loss: 6.6782 - model_1_3_loss: 0.0428 - model_1_accuracy: 0.7851 - model_1_1_accuracy: 0.7124 - model_1_2_accuracy: 0.6759 - model_1_3_accuracy: 0.6489
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.4842 - model_1_loss: 1.2466 - model_1_1_loss: 3.7120 - model_1_2_loss: 6.4841 - model_1_3_loss: 0.0413 - model_1_accuracy: 0.7855 - model_1_1_accuracy: 0.7126 - model_1_2_accuracy: 0.6779 - model_1_3_accuracy: 0.6528
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.1936 - model_1_loss: 1.2519 - model_1_1_loss: 3.6263 - model_1_2_loss: 6.2753 - model_1_3_loss: 0.0399 - model_1_accuracy: 0.7856 - model_1_1_accuracy: 0.7175 - model_1_2_accuracy: 0.6821 - model_1_3_accuracy: 0.6528
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.9050 - model_1_loss: 1.2564 - model_1_1_loss: 3.5286 - model_1_2_loss: 6.0809 - model_1_3_loss: 0.0389 - model_1_accuracy: 0.7860 - model_1_1_accuracy: 0.7245 - model_1_2_accuracy: 0.6839 - model_1_3_accuracy: 0.6644
#
# --------------------Mini Batch No. 1469/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 3ms/step - loss: 6.2499 - model_1_loss: 0.6307 - model_1_1_loss: 1.9737 - model_1_2_loss: 3.6270 - model_1_3_loss: 0.0184 - model_1_accuracy: 0.8511 - model_1_1_accuracy: 0.7578 - model_1_2_accuracy: 0.7358 - model_1_3_accuracy: 0.7145
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 6.2834 - model_1_loss: 0.6358 - model_1_1_loss: 1.9909 - model_1_2_loss: 3.6382 - model_1_3_loss: 0.0183 - model_1_accuracy: 0.8504 - model_1_1_accuracy: 0.7544 - model_1_2_accuracy: 0.7316 - model_1_3_accuracy: 0.7153
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1713 - model_1_loss: 0.6277 - model_1_1_loss: 1.9588 - model_1_2_loss: 3.5667 - model_1_3_loss: 0.0181 - model_1_accuracy: 0.8501 - model_1_1_accuracy: 0.7554 - model_1_2_accuracy: 0.7341 - model_1_3_accuracy: 0.7176
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0246 - model_1_loss: 0.6163 - model_1_1_loss: 1.9176 - model_1_2_loss: 3.4727 - model_1_3_loss: 0.0178 - model_1_accuracy: 0.8506 - model_1_1_accuracy: 0.7590 - model_1_2_accuracy: 0.7374 - model_1_3_accuracy: 0.7160
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9387 - model_1_loss: 0.6091 - model_1_1_loss: 1.8997 - model_1_2_loss: 3.4122 - model_1_3_loss: 0.0176 - model_1_accuracy: 0.8511 - model_1_1_accuracy: 0.7653 - model_1_2_accuracy: 0.7369 - model_1_3_accuracy: 0.7191
#
# --------------------Mini Batch No. 1470/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3499 - model_1_loss: 0.8712 - model_1_1_loss: 2.7992 - model_1_2_loss: 5.6503 - model_1_3_loss: 0.0291 - model_1_accuracy: 0.8266 - model_1_1_accuracy: 0.7256 - model_1_2_accuracy: 0.6927 - model_1_3_accuracy: 0.6543
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.2881 - model_1_loss: 0.8636 - model_1_1_loss: 2.7787 - model_1_2_loss: 5.6168 - model_1_3_loss: 0.0289 - model_1_accuracy: 0.8282 - model_1_1_accuracy: 0.7273 - model_1_2_accuracy: 0.6949 - model_1_3_accuracy: 0.6582
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1478 - model_1_loss: 0.8558 - model_1_1_loss: 2.7389 - model_1_2_loss: 5.5245 - model_1_3_loss: 0.0285 - model_1_accuracy: 0.8296 - model_1_1_accuracy: 0.7320 - model_1_2_accuracy: 0.7011 - model_1_3_accuracy: 0.6644
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9687 - model_1_loss: 0.8520 - model_1_1_loss: 2.6984 - model_1_2_loss: 5.3904 - model_1_3_loss: 0.0278 - model_1_accuracy: 0.8300 - model_1_1_accuracy: 0.7360 - model_1_2_accuracy: 0.7087 - model_1_3_accuracy: 0.6651
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7714 - model_1_loss: 0.8499 - model_1_1_loss: 2.6621 - model_1_2_loss: 5.2325 - model_1_3_loss: 0.0268 - model_1_accuracy: 0.8309 - model_1_1_accuracy: 0.7390 - model_1_2_accuracy: 0.7184 - model_1_3_accuracy: 0.6721
#
# --------------------Mini Batch No. 1471/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 10.5466 - model_1_loss: 0.9648 - model_1_1_loss: 3.1161 - model_1_2_loss: 6.4308 - model_1_3_loss: 0.0347 - model_1_accuracy: 0.8220 - model_1_1_accuracy: 0.7325 - model_1_2_accuracy: 0.7182 - model_1_3_accuracy: 0.6906
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3747 - model_1_loss: 0.9693 - model_1_1_loss: 3.0864 - model_1_2_loss: 6.2849 - model_1_3_loss: 0.0340 - model_1_accuracy: 0.8218 - model_1_1_accuracy: 0.7339 - model_1_2_accuracy: 0.7226 - model_1_3_accuracy: 0.6937
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1383 - model_1_loss: 0.9739 - model_1_1_loss: 3.0407 - model_1_2_loss: 6.0908 - model_1_3_loss: 0.0328 - model_1_accuracy: 0.8222 - model_1_1_accuracy: 0.7354 - model_1_2_accuracy: 0.7237 - model_1_3_accuracy: 0.6952
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.8973 - model_1_loss: 0.9767 - model_1_1_loss: 2.9916 - model_1_2_loss: 5.8973 - model_1_3_loss: 0.0315 - model_1_accuracy: 0.8223 - model_1_1_accuracy: 0.7363 - model_1_2_accuracy: 0.7255 - model_1_3_accuracy: 0.7052
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.6702 - model_1_loss: 0.9749 - model_1_1_loss: 2.9413 - model_1_2_loss: 5.7236 - model_1_3_loss: 0.0303 - model_1_accuracy: 0.8219 - model_1_1_accuracy: 0.7391 - model_1_2_accuracy: 0.7299 - model_1_3_accuracy: 0.7199
#
# --------------------Mini Batch No. 1472/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.2363 - model_1_loss: 0.6805 - model_1_1_loss: 2.0365 - model_1_2_loss: 3.5012 - model_1_3_loss: 0.0180 - model_1_accuracy: 0.8225 - model_1_1_accuracy: 0.7168 - model_1_2_accuracy: 0.7288 - model_1_3_accuracy: 0.7029
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1492 - model_1_loss: 0.6750 - model_1_1_loss: 2.0104 - model_1_2_loss: 3.4459 - model_1_3_loss: 0.0179 - model_1_accuracy: 0.8226 - model_1_1_accuracy: 0.7182 - model_1_2_accuracy: 0.7325 - model_1_3_accuracy: 0.7099
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.0195 - model_1_loss: 0.6664 - model_1_1_loss: 1.9721 - model_1_2_loss: 3.3633 - model_1_3_loss: 0.0176 - model_1_accuracy: 0.8236 - model_1_1_accuracy: 0.7208 - model_1_2_accuracy: 0.7372 - model_1_3_accuracy: 0.7114
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8776 - model_1_loss: 0.6564 - model_1_1_loss: 1.9289 - model_1_2_loss: 3.2747 - model_1_3_loss: 0.0174 - model_1_accuracy: 0.8248 - model_1_1_accuracy: 0.7235 - model_1_2_accuracy: 0.7458 - model_1_3_accuracy: 0.7130
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.7459 - model_1_loss: 0.6471 - model_1_1_loss: 1.8856 - model_1_2_loss: 3.1959 - model_1_3_loss: 0.0171 - model_1_accuracy: 0.8262 - model_1_1_accuracy: 0.7275 - model_1_2_accuracy: 0.7478 - model_1_3_accuracy: 0.7114
#
# --------------------Mini Batch No. 1473/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.7519 - model_1_loss: 1.0444 - model_1_1_loss: 3.3337 - model_1_2_loss: 6.3401 - model_1_3_loss: 0.0336 - model_1_accuracy: 0.7791 - model_1_1_accuracy: 0.6448 - model_1_2_accuracy: 0.6813 - model_1_3_accuracy: 0.6319
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.5938 - model_1_loss: 1.0349 - model_1_1_loss: 3.2908 - model_1_2_loss: 6.2350 - model_1_3_loss: 0.0329 - model_1_accuracy: 0.7803 - model_1_1_accuracy: 0.6466 - model_1_2_accuracy: 0.6843 - model_1_3_accuracy: 0.6281
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3977 - model_1_loss: 1.0277 - model_1_1_loss: 3.2423 - model_1_2_loss: 6.0955 - model_1_3_loss: 0.0321 - model_1_accuracy: 0.7806 - model_1_1_accuracy: 0.6493 - model_1_2_accuracy: 0.6928 - model_1_3_accuracy: 0.6358
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1810 - model_1_loss: 1.0220 - model_1_1_loss: 3.1871 - model_1_2_loss: 5.9406 - model_1_3_loss: 0.0312 - model_1_accuracy: 0.7816 - model_1_1_accuracy: 0.6528 - model_1_2_accuracy: 0.7034 - model_1_3_accuracy: 0.6435
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9756 - model_1_loss: 1.0159 - model_1_1_loss: 3.1317 - model_1_2_loss: 5.7976 - model_1_3_loss: 0.0304 - model_1_accuracy: 0.7828 - model_1_1_accuracy: 0.6554 - model_1_2_accuracy: 0.7080 - model_1_3_accuracy: 0.6543
#
# --------------------Mini Batch No. 1474/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7567 - model_1_loss: 0.5000 - model_1_1_loss: 1.4949 - model_1_2_loss: 2.7473 - model_1_3_loss: 0.0143 - model_1_accuracy: 0.8565 - model_1_1_accuracy: 0.7704 - model_1_2_accuracy: 0.7653 - model_1_3_accuracy: 0.7454
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 4.7435 - model_1_loss: 0.5018 - model_1_1_loss: 1.4918 - model_1_2_loss: 2.7356 - model_1_3_loss: 0.0142 - model_1_accuracy: 0.8566 - model_1_1_accuracy: 0.7701 - model_1_2_accuracy: 0.7666 - model_1_3_accuracy: 0.7461
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6865 - model_1_loss: 0.5001 - model_1_1_loss: 1.4767 - model_1_2_loss: 2.6957 - model_1_3_loss: 0.0139 - model_1_accuracy: 0.8573 - model_1_1_accuracy: 0.7714 - model_1_2_accuracy: 0.7690 - model_1_3_accuracy: 0.7500
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5902 - model_1_loss: 0.4946 - model_1_1_loss: 1.4503 - model_1_2_loss: 2.6316 - model_1_3_loss: 0.0135 - model_1_accuracy: 0.8588 - model_1_1_accuracy: 0.7731 - model_1_2_accuracy: 0.7717 - model_1_3_accuracy: 0.7554
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4755 - model_1_loss: 0.4870 - model_1_1_loss: 1.4183 - model_1_2_loss: 2.5569 - model_1_3_loss: 0.0131 - model_1_accuracy: 0.8612 - model_1_1_accuracy: 0.7760 - model_1_2_accuracy: 0.7730 - model_1_3_accuracy: 0.7600
#
# --------------------Mini Batch No. 1475/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8680 - model_1_loss: 0.7460 - model_1_1_loss: 2.5959 - model_1_2_loss: 5.4942 - model_1_3_loss: 0.0318 - model_1_accuracy: 0.8573 - model_1_1_accuracy: 0.7743 - model_1_2_accuracy: 0.6875 - model_1_3_accuracy: 0.6813
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7706 - model_1_loss: 0.7442 - model_1_1_loss: 2.5740 - model_1_2_loss: 5.4208 - model_1_3_loss: 0.0316 - model_1_accuracy: 0.8571 - model_1_1_accuracy: 0.7741 - model_1_2_accuracy: 0.6841 - model_1_3_accuracy: 0.6813
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6247 - model_1_loss: 0.7432 - model_1_1_loss: 2.5410 - model_1_2_loss: 5.3094 - model_1_3_loss: 0.0310 - model_1_accuracy: 0.8569 - model_1_1_accuracy: 0.7745 - model_1_2_accuracy: 0.6852 - model_1_3_accuracy: 0.6852
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4718 - model_1_loss: 0.7445 - model_1_1_loss: 2.5079 - model_1_2_loss: 5.1891 - model_1_3_loss: 0.0302 - model_1_accuracy: 0.8568 - model_1_1_accuracy: 0.7748 - model_1_2_accuracy: 0.6879 - model_1_3_accuracy: 0.6906
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3276 - model_1_loss: 0.7461 - model_1_1_loss: 2.4775 - model_1_2_loss: 5.0746 - model_1_3_loss: 0.0294 - model_1_accuracy: 0.8563 - model_1_1_accuracy: 0.7754 - model_1_2_accuracy: 0.6901 - model_1_3_accuracy: 0.6890
#
# --------------------Mini Batch No. 1476/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3227 - model_1_loss: 0.9875 - model_1_1_loss: 2.7867 - model_1_2_loss: 5.5198 - model_1_3_loss: 0.0287 - model_1_accuracy: 0.8170 - model_1_1_accuracy: 0.6856 - model_1_2_accuracy: 0.6740 - model_1_3_accuracy: 0.6998
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.1531 - model_1_loss: 0.9880 - model_1_1_loss: 2.7573 - model_1_2_loss: 5.3800 - model_1_3_loss: 0.0278 - model_1_accuracy: 0.8165 - model_1_1_accuracy: 0.6870 - model_1_2_accuracy: 0.6819 - model_1_3_accuracy: 0.7006
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9397 - model_1_loss: 0.9882 - model_1_1_loss: 2.7199 - model_1_2_loss: 5.2048 - model_1_3_loss: 0.0267 - model_1_accuracy: 0.8166 - model_1_1_accuracy: 0.6866 - model_1_2_accuracy: 0.6885 - model_1_3_accuracy: 0.7145
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.7707 - model_1_loss: 0.9906 - model_1_1_loss: 2.6911 - model_1_2_loss: 5.0633 - model_1_3_loss: 0.0257 - model_1_accuracy: 0.8164 - model_1_1_accuracy: 0.6900 - model_1_2_accuracy: 0.6998 - model_1_3_accuracy: 0.7199
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6282 - model_1_loss: 0.9918 - model_1_1_loss: 2.6626 - model_1_2_loss: 4.9489 - model_1_3_loss: 0.0247 - model_1_accuracy: 0.8159 - model_1_1_accuracy: 0.6922 - model_1_2_accuracy: 0.7075 - model_1_3_accuracy: 0.7261
#
# --------------------Mini Batch No. 1477/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4790 - model_1_loss: 0.8068 - model_1_1_loss: 2.3555 - model_1_2_loss: 4.2954 - model_1_3_loss: 0.0213 - model_1_accuracy: 0.8065 - model_1_1_accuracy: 0.7160 - model_1_2_accuracy: 0.7317 - model_1_3_accuracy: 0.7022
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3179 - model_1_loss: 0.7951 - model_1_1_loss: 2.3116 - model_1_2_loss: 4.1904 - model_1_3_loss: 0.0207 - model_1_accuracy: 0.8091 - model_1_1_accuracy: 0.7167 - model_1_2_accuracy: 0.7363 - model_1_3_accuracy: 0.7006
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.1258 - model_1_loss: 0.7763 - model_1_1_loss: 2.2578 - model_1_2_loss: 4.0711 - model_1_3_loss: 0.0204 - model_1_accuracy: 0.8127 - model_1_1_accuracy: 0.7208 - model_1_2_accuracy: 0.7396 - model_1_3_accuracy: 0.7014
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0003 - model_1_loss: 0.7588 - model_1_1_loss: 2.2153 - model_1_2_loss: 4.0054 - model_1_3_loss: 0.0205 - model_1_accuracy: 0.8153 - model_1_1_accuracy: 0.7256 - model_1_2_accuracy: 0.7378 - model_1_3_accuracy: 0.7052
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9352 - model_1_loss: 0.7462 - model_1_1_loss: 2.1865 - model_1_2_loss: 3.9815 - model_1_3_loss: 0.0208 - model_1_accuracy: 0.8167 - model_1_1_accuracy: 0.7286 - model_1_2_accuracy: 0.7392 - model_1_3_accuracy: 0.7029
#
# --------------------Mini Batch No. 1478/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.9705 - model_1_loss: 1.0664 - model_1_1_loss: 3.5424 - model_1_2_loss: 7.3182 - model_1_3_loss: 0.0434 - model_1_accuracy: 0.8085 - model_1_1_accuracy: 0.7087 - model_1_2_accuracy: 0.6240 - model_1_3_accuracy: 0.6073
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.7446 - model_1_loss: 1.0585 - model_1_1_loss: 3.4874 - model_1_2_loss: 7.1563 - model_1_3_loss: 0.0424 - model_1_accuracy: 0.8105 - model_1_1_accuracy: 0.7123 - model_1_2_accuracy: 0.6317 - model_1_3_accuracy: 0.6165
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.4637 - model_1_loss: 1.0549 - model_1_1_loss: 3.4246 - model_1_2_loss: 6.9433 - model_1_3_loss: 0.0409 - model_1_accuracy: 0.8119 - model_1_1_accuracy: 0.7145 - model_1_2_accuracy: 0.6350 - model_1_3_accuracy: 0.6142
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.1916 - model_1_loss: 1.0551 - model_1_1_loss: 3.3594 - model_1_2_loss: 6.7377 - model_1_3_loss: 0.0394 - model_1_accuracy: 0.8121 - model_1_1_accuracy: 0.7155 - model_1_2_accuracy: 0.6454 - model_1_3_accuracy: 0.6134
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.9848 - model_1_loss: 1.0565 - model_1_1_loss: 3.3086 - model_1_2_loss: 6.5817 - model_1_3_loss: 0.0379 - model_1_accuracy: 0.8114 - model_1_1_accuracy: 0.7175 - model_1_2_accuracy: 0.6525 - model_1_3_accuracy: 0.6134
#
# --------------------Mini Batch No. 1479/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.3435 - model_1_loss: 0.5970 - model_1_1_loss: 1.6719 - model_1_2_loss: 3.0584 - model_1_3_loss: 0.0163 - model_1_accuracy: 0.8561 - model_1_1_accuracy: 0.8071 - model_1_2_accuracy: 0.7657 - model_1_3_accuracy: 0.7631
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.3369 - model_1_loss: 0.5970 - model_1_1_loss: 1.6689 - model_1_2_loss: 3.0547 - model_1_3_loss: 0.0163 - model_1_accuracy: 0.8562 - model_1_1_accuracy: 0.8079 - model_1_2_accuracy: 0.7659 - model_1_3_accuracy: 0.7654
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.2818 - model_1_loss: 0.5921 - model_1_1_loss: 1.6548 - model_1_2_loss: 3.0186 - model_1_3_loss: 0.0162 - model_1_accuracy: 0.8572 - model_1_1_accuracy: 0.8075 - model_1_2_accuracy: 0.7673 - model_1_3_accuracy: 0.7701
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1761 - model_1_loss: 0.5825 - model_1_1_loss: 1.6268 - model_1_2_loss: 2.9508 - model_1_3_loss: 0.0159 - model_1_accuracy: 0.8587 - model_1_1_accuracy: 0.8095 - model_1_2_accuracy: 0.7708 - model_1_3_accuracy: 0.7793
# Epoch 5/5
# 1/1 [==============================] - 0s 1ms/step - loss: 5.0390 - model_1_loss: 0.5684 - model_1_1_loss: 1.5888 - model_1_2_loss: 2.8663 - model_1_3_loss: 0.0154 - model_1_accuracy: 0.8605 - model_1_1_accuracy: 0.8118 - model_1_2_accuracy: 0.7789 - model_1_3_accuracy: 0.7816
#
# --------------------Mini Batch No. 1480/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.2140 - model_1_loss: 0.7653 - model_1_1_loss: 2.3454 - model_1_2_loss: 5.0737 - model_1_3_loss: 0.0295 - model_1_accuracy: 0.8586 - model_1_1_accuracy: 0.7718 - model_1_2_accuracy: 0.7226 - model_1_3_accuracy: 0.6944
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.9647 - model_1_loss: 0.7425 - model_1_1_loss: 2.2722 - model_1_2_loss: 4.9211 - model_1_3_loss: 0.0287 - model_1_accuracy: 0.8609 - model_1_1_accuracy: 0.7783 - model_1_2_accuracy: 0.7149 - model_1_3_accuracy: 0.6898
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.7122 - model_1_loss: 0.7257 - model_1_1_loss: 2.2054 - model_1_2_loss: 4.7529 - model_1_3_loss: 0.0280 - model_1_accuracy: 0.8648 - model_1_1_accuracy: 0.7886 - model_1_2_accuracy: 0.7184 - model_1_3_accuracy: 0.6806
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4521 - model_1_loss: 0.7135 - model_1_1_loss: 2.1443 - model_1_2_loss: 4.5670 - model_1_3_loss: 0.0271 - model_1_accuracy: 0.8682 - model_1_1_accuracy: 0.7949 - model_1_2_accuracy: 0.7232 - model_1_3_accuracy: 0.6944
# Epoch 5/5
# 1/1 [==============================] - 0s 4ms/step - loss: 7.1586 - model_1_loss: 0.7002 - model_1_1_loss: 2.0762 - model_1_2_loss: 4.3560 - model_1_3_loss: 0.0261 - model_1_accuracy: 0.8722 - model_1_1_accuracy: 0.7983 - model_1_2_accuracy: 0.7297 - model_1_3_accuracy: 0.7060
#
# --------------------Mini Batch No. 1481/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 4ms/step - loss: 13.5696 - model_1_loss: 1.1163 - model_1_1_loss: 4.0132 - model_1_2_loss: 8.3908 - model_1_3_loss: 0.0493 - model_1_accuracy: 0.8028 - model_1_1_accuracy: 0.6760 - model_1_2_accuracy: 0.6377 - model_1_3_accuracy: 0.6227
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.4495 - model_1_loss: 1.1242 - model_1_1_loss: 3.9852 - model_1_2_loss: 8.2915 - model_1_3_loss: 0.0484 - model_1_accuracy: 0.8019 - model_1_1_accuracy: 0.6762 - model_1_2_accuracy: 0.6415 - model_1_3_accuracy: 0.6265
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.2306 - model_1_loss: 1.1336 - model_1_1_loss: 3.9314 - model_1_2_loss: 8.1182 - model_1_3_loss: 0.0474 - model_1_accuracy: 0.8006 - model_1_1_accuracy: 0.6800 - model_1_2_accuracy: 0.6448 - model_1_3_accuracy: 0.6281
# Epoch 4/5
# 1/1 [==============================] - 0s 1ms/step - loss: 12.9054 - model_1_loss: 1.1377 - model_1_1_loss: 3.8511 - model_1_2_loss: 7.8707 - model_1_3_loss: 0.0459 - model_1_accuracy: 0.8004 - model_1_1_accuracy: 0.6851 - model_1_2_accuracy: 0.6476 - model_1_3_accuracy: 0.6373
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.5038 - model_1_loss: 1.1335 - model_1_1_loss: 3.7504 - model_1_2_loss: 7.5758 - model_1_3_loss: 0.0441 - model_1_accuracy: 0.7995 - model_1_1_accuracy: 0.6892 - model_1_2_accuracy: 0.6550 - model_1_3_accuracy: 0.6350
#
# --------------------Mini Batch No. 1482/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5169 - model_1_loss: 0.4246 - model_1_1_loss: 1.3891 - model_1_2_loss: 2.6883 - model_1_3_loss: 0.0148 - model_1_accuracy: 0.8756 - model_1_1_accuracy: 0.7981 - model_1_2_accuracy: 0.7798 - model_1_3_accuracy: 0.7616
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.4534 - model_1_loss: 0.4223 - model_1_1_loss: 1.3700 - model_1_2_loss: 2.6468 - model_1_3_loss: 0.0143 - model_1_accuracy: 0.8758 - model_1_1_accuracy: 0.7974 - model_1_2_accuracy: 0.7814 - model_1_3_accuracy: 0.7670
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.2227 - model_1_loss: 0.4121 - model_1_1_loss: 1.3059 - model_1_2_loss: 2.4913 - model_1_3_loss: 0.0133 - model_1_accuracy: 0.8778 - model_1_1_accuracy: 0.8010 - model_1_2_accuracy: 0.7843 - model_1_3_accuracy: 0.7739
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9012 - model_1_loss: 0.3967 - model_1_1_loss: 1.2181 - model_1_2_loss: 2.2741 - model_1_3_loss: 0.0122 - model_1_accuracy: 0.8811 - model_1_1_accuracy: 0.8042 - model_1_2_accuracy: 0.7931 - model_1_3_accuracy: 0.7840
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6328 - model_1_loss: 0.3832 - model_1_1_loss: 1.1450 - model_1_2_loss: 2.0933 - model_1_3_loss: 0.0112 - model_1_accuracy: 0.8847 - model_1_1_accuracy: 0.8067 - model_1_2_accuracy: 0.8008 - model_1_3_accuracy: 0.7955
#
# --------------------Mini Batch No. 1483/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.0256 - model_1_loss: 1.1695 - model_1_1_loss: 3.9222 - model_1_2_loss: 7.8929 - model_1_3_loss: 0.0409 - model_1_accuracy: 0.7776 - model_1_1_accuracy: 0.6873 - model_1_2_accuracy: 0.6497 - model_1_3_accuracy: 0.5810
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.9042 - model_1_loss: 1.1639 - model_1_1_loss: 3.8849 - model_1_2_loss: 7.8152 - model_1_3_loss: 0.0401 - model_1_accuracy: 0.7778 - model_1_1_accuracy: 0.6884 - model_1_2_accuracy: 0.6536 - model_1_3_accuracy: 0.5802
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 12.5003 - model_1_loss: 1.1623 - model_1_1_loss: 3.7909 - model_1_2_loss: 7.5094 - model_1_3_loss: 0.0377 - model_1_accuracy: 0.7779 - model_1_1_accuracy: 0.6910 - model_1_2_accuracy: 0.6647 - model_1_3_accuracy: 0.5934
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1491 - model_1_loss: 1.1702 - model_1_1_loss: 3.7123 - model_1_2_loss: 7.2312 - model_1_3_loss: 0.0354 - model_1_accuracy: 0.7771 - model_1_1_accuracy: 0.6940 - model_1_2_accuracy: 0.6713 - model_1_3_accuracy: 0.6049
# Epoch 5/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.9593 - model_1_loss: 1.1855 - model_1_1_loss: 3.6764 - model_1_2_loss: 7.0635 - model_1_3_loss: 0.0340 - model_1_accuracy: 0.7750 - model_1_1_accuracy: 0.6956 - model_1_2_accuracy: 0.6715 - model_1_3_accuracy: 0.6157
#
# --------------------Mini Batch No. 1484/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.1562 - model_1_loss: 0.7234 - model_1_1_loss: 1.9012 - model_1_2_loss: 3.5140 - model_1_3_loss: 0.0175 - model_1_accuracy: 0.8305 - model_1_1_accuracy: 0.7783 - model_1_2_accuracy: 0.7467 - model_1_3_accuracy: 0.7446
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 6.0588 - model_1_loss: 0.7104 - model_1_1_loss: 1.8714 - model_1_2_loss: 3.4596 - model_1_3_loss: 0.0172 - model_1_accuracy: 0.8314 - model_1_1_accuracy: 0.7752 - model_1_2_accuracy: 0.7491 - model_1_3_accuracy: 0.7515
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8416 - model_1_loss: 0.6817 - model_1_1_loss: 1.7987 - model_1_2_loss: 3.3441 - model_1_3_loss: 0.0169 - model_1_accuracy: 0.8342 - model_1_1_accuracy: 0.7787 - model_1_2_accuracy: 0.7558 - model_1_3_accuracy: 0.7608
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.6328 - model_1_loss: 0.6543 - model_1_1_loss: 1.7289 - model_1_2_loss: 3.2325 - model_1_3_loss: 0.0170 - model_1_accuracy: 0.8390 - model_1_1_accuracy: 0.7817 - model_1_2_accuracy: 0.7635 - model_1_3_accuracy: 0.7569
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4330 - model_1_loss: 0.6277 - model_1_1_loss: 1.6702 - model_1_2_loss: 3.1181 - model_1_3_loss: 0.0169 - model_1_accuracy: 0.8448 - model_1_1_accuracy: 0.7851 - model_1_2_accuracy: 0.7721 - model_1_3_accuracy: 0.7631
#
# --------------------Mini Batch No. 1485/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0258 - model_1_loss: 0.9795 - model_1_1_loss: 3.0709 - model_1_2_loss: 5.9458 - model_1_3_loss: 0.0295 - model_1_accuracy: 0.8153 - model_1_1_accuracy: 0.7080 - model_1_2_accuracy: 0.6511 - model_1_3_accuracy: 0.6780
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0309 - model_1_loss: 0.9713 - model_1_1_loss: 3.0740 - model_1_2_loss: 5.9558 - model_1_3_loss: 0.0298 - model_1_accuracy: 0.8159 - model_1_1_accuracy: 0.7081 - model_1_2_accuracy: 0.6516 - model_1_3_accuracy: 0.6831
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9475 - model_1_loss: 0.9666 - model_1_1_loss: 3.0492 - model_1_2_loss: 5.9021 - model_1_3_loss: 0.0295 - model_1_accuracy: 0.8167 - model_1_1_accuracy: 0.7083 - model_1_2_accuracy: 0.6533 - model_1_3_accuracy: 0.6831
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.7016 - model_1_loss: 0.9587 - model_1_1_loss: 2.9785 - model_1_2_loss: 5.7358 - model_1_3_loss: 0.0285 - model_1_accuracy: 0.8175 - model_1_1_accuracy: 0.7133 - model_1_2_accuracy: 0.6584 - model_1_3_accuracy: 0.6883
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.3936 - model_1_loss: 0.9531 - model_1_1_loss: 2.8922 - model_1_2_loss: 5.5212 - model_1_3_loss: 0.0270 - model_1_accuracy: 0.8181 - model_1_1_accuracy: 0.7166 - model_1_2_accuracy: 0.6664 - model_1_3_accuracy: 0.6955
#
# --------------------Mini Batch No. 1486/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9299 - model_1_loss: 0.4174 - model_1_1_loss: 1.2550 - model_1_2_loss: 2.2461 - model_1_3_loss: 0.0113 - model_1_accuracy: 0.8834 - model_1_1_accuracy: 0.8097 - model_1_2_accuracy: 0.8083 - model_1_3_accuracy: 0.7886
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9016 - model_1_loss: 0.4222 - model_1_1_loss: 1.2532 - model_1_2_loss: 2.2152 - model_1_3_loss: 0.0109 - model_1_accuracy: 0.8822 - model_1_1_accuracy: 0.8062 - model_1_2_accuracy: 0.8072 - model_1_3_accuracy: 0.7971
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.8475 - model_1_loss: 0.4247 - model_1_1_loss: 1.2417 - model_1_2_loss: 2.1705 - model_1_3_loss: 0.0105 - model_1_accuracy: 0.8816 - model_1_1_accuracy: 0.8075 - model_1_2_accuracy: 0.8064 - model_1_3_accuracy: 0.8002
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.7604 - model_1_loss: 0.4231 - model_1_1_loss: 1.2183 - model_1_2_loss: 2.1089 - model_1_3_loss: 0.0101 - model_1_accuracy: 0.8823 - model_1_1_accuracy: 0.8096 - model_1_2_accuracy: 0.8066 - model_1_3_accuracy: 0.8032
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 3.6426 - model_1_loss: 0.4171 - model_1_1_loss: 1.1843 - model_1_2_loss: 2.0315 - model_1_3_loss: 0.0097 - model_1_accuracy: 0.8833 - model_1_1_accuracy: 0.8136 - model_1_2_accuracy: 0.8046 - model_1_3_accuracy: 0.8086
#
# --------------------Mini Batch No. 1487/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 7.8185 - model_1_loss: 0.9654 - model_1_1_loss: 2.5746 - model_1_2_loss: 4.2584 - model_1_3_loss: 0.0200 - model_1_accuracy: 0.8034 - model_1_1_accuracy: 0.7158 - model_1_2_accuracy: 0.7151 - model_1_3_accuracy: 0.6844
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6862 - model_1_loss: 0.9566 - model_1_1_loss: 2.5403 - model_1_2_loss: 4.1697 - model_1_3_loss: 0.0195 - model_1_accuracy: 0.8045 - model_1_1_accuracy: 0.7187 - model_1_2_accuracy: 0.7191 - model_1_3_accuracy: 0.6836
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.5286 - model_1_loss: 0.9436 - model_1_1_loss: 2.4972 - model_1_2_loss: 4.0685 - model_1_3_loss: 0.0191 - model_1_accuracy: 0.8065 - model_1_1_accuracy: 0.7202 - model_1_2_accuracy: 0.7255 - model_1_3_accuracy: 0.6836
# Epoch 4/5
# 1/1 [==============================] - 0s 1ms/step - loss: 7.4057 - model_1_loss: 0.9320 - model_1_1_loss: 2.4621 - model_1_2_loss: 3.9926 - model_1_3_loss: 0.0189 - model_1_accuracy: 0.8083 - model_1_1_accuracy: 0.7209 - model_1_2_accuracy: 0.7277 - model_1_3_accuracy: 0.6890
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.3314 - model_1_loss: 0.9251 - model_1_1_loss: 2.4416 - model_1_2_loss: 3.9459 - model_1_3_loss: 0.0188 - model_1_accuracy: 0.8100 - model_1_1_accuracy: 0.7207 - model_1_2_accuracy: 0.7312 - model_1_3_accuracy: 0.6937
#
# --------------------Mini Batch No. 1488/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.7368 - model_1_loss: 0.9787 - model_1_1_loss: 3.4019 - model_1_2_loss: 6.3225 - model_1_3_loss: 0.0337 - model_1_accuracy: 0.8037 - model_1_1_accuracy: 0.6733 - model_1_2_accuracy: 0.6996 - model_1_3_accuracy: 0.6119
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.6186 - model_1_loss: 0.9768 - model_1_1_loss: 3.3672 - model_1_2_loss: 6.2414 - model_1_3_loss: 0.0332 - model_1_accuracy: 0.8035 - model_1_1_accuracy: 0.6752 - model_1_2_accuracy: 0.7009 - model_1_3_accuracy: 0.6173
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3914 - model_1_loss: 0.9747 - model_1_1_loss: 3.3013 - model_1_2_loss: 6.0833 - model_1_3_loss: 0.0321 - model_1_accuracy: 0.8040 - model_1_1_accuracy: 0.6765 - model_1_2_accuracy: 0.7007 - model_1_3_accuracy: 0.6235
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.1377 - model_1_loss: 0.9739 - model_1_1_loss: 3.2258 - model_1_2_loss: 5.9073 - model_1_3_loss: 0.0307 - model_1_accuracy: 0.8040 - model_1_1_accuracy: 0.6792 - model_1_2_accuracy: 0.7049 - model_1_3_accuracy: 0.6281
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.9022 - model_1_loss: 0.9754 - model_1_1_loss: 3.1518 - model_1_2_loss: 5.7456 - model_1_3_loss: 0.0293 - model_1_accuracy: 0.8039 - model_1_1_accuracy: 0.6824 - model_1_2_accuracy: 0.7064 - model_1_3_accuracy: 0.6319
#
# --------------------Mini Batch No. 1489/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8653 - model_1_loss: 0.8717 - model_1_1_loss: 2.4508 - model_1_2_loss: 4.5214 - model_1_3_loss: 0.0213 - model_1_accuracy: 0.8314 - model_1_1_accuracy: 0.7174 - model_1_2_accuracy: 0.7160 - model_1_3_accuracy: 0.7477
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.8266 - model_1_loss: 0.8699 - model_1_1_loss: 2.4361 - model_1_2_loss: 4.4994 - model_1_3_loss: 0.0212 - model_1_accuracy: 0.8320 - model_1_1_accuracy: 0.7162 - model_1_2_accuracy: 0.7140 - model_1_3_accuracy: 0.7461
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 7.7262 - model_1_loss: 0.8551 - model_1_1_loss: 2.3988 - model_1_2_loss: 4.4511 - model_1_3_loss: 0.0212 - model_1_accuracy: 0.8345 - model_1_1_accuracy: 0.7164 - model_1_2_accuracy: 0.7146 - model_1_3_accuracy: 0.7461
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.5944 - model_1_loss: 0.8313 - model_1_1_loss: 2.3519 - model_1_2_loss: 4.3898 - model_1_3_loss: 0.0214 - model_1_accuracy: 0.8371 - model_1_1_accuracy: 0.7182 - model_1_2_accuracy: 0.7184 - model_1_3_accuracy: 0.7438
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.4998 - model_1_loss: 0.8092 - model_1_1_loss: 2.3184 - model_1_2_loss: 4.3504 - model_1_3_loss: 0.0217 - model_1_accuracy: 0.8393 - model_1_1_accuracy: 0.7199 - model_1_2_accuracy: 0.7230 - model_1_3_accuracy: 0.7461
#
# --------------------Mini Batch No. 1490/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.6384 - model_1_loss: 1.2179 - model_1_1_loss: 3.6980 - model_1_2_loss: 7.6808 - model_1_3_loss: 0.0416 - model_1_accuracy: 0.8139 - model_1_1_accuracy: 0.7443 - model_1_2_accuracy: 0.6833 - model_1_3_accuracy: 0.6543
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.4054 - model_1_loss: 1.2014 - model_1_1_loss: 3.6378 - model_1_2_loss: 7.5250 - model_1_3_loss: 0.0412 - model_1_accuracy: 0.8156 - model_1_1_accuracy: 0.7496 - model_1_2_accuracy: 0.6881 - model_1_3_accuracy: 0.6528
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.0250 - model_1_loss: 1.1848 - model_1_1_loss: 3.5366 - model_1_2_loss: 7.2634 - model_1_3_loss: 0.0401 - model_1_accuracy: 0.8172 - model_1_1_accuracy: 0.7573 - model_1_2_accuracy: 0.6972 - model_1_3_accuracy: 0.6605
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.5916 - model_1_loss: 1.1701 - model_1_1_loss: 3.4231 - model_1_2_loss: 6.9597 - model_1_3_loss: 0.0385 - model_1_accuracy: 0.8191 - model_1_1_accuracy: 0.7614 - model_1_2_accuracy: 0.7080 - model_1_3_accuracy: 0.6713
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.1611 - model_1_loss: 1.1592 - model_1_1_loss: 3.3142 - model_1_2_loss: 6.6508 - model_1_3_loss: 0.0368 - model_1_accuracy: 0.8216 - model_1_1_accuracy: 0.7653 - model_1_2_accuracy: 0.7142 - model_1_3_accuracy: 0.6798
#
# --------------------Mini Batch No. 1491/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 14.3723 - model_1_loss: 1.3121 - model_1_1_loss: 4.1753 - model_1_2_loss: 8.8306 - model_1_3_loss: 0.0543 - model_1_accuracy: 0.7946 - model_1_1_accuracy: 0.6993 - model_1_2_accuracy: 0.6200 - model_1_3_accuracy: 0.5826
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 14.2223 - model_1_loss: 1.3300 - model_1_1_loss: 4.1518 - model_1_2_loss: 8.6875 - model_1_3_loss: 0.0529 - model_1_accuracy: 0.7932 - model_1_1_accuracy: 0.7014 - model_1_2_accuracy: 0.6081 - model_1_3_accuracy: 0.5918
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 14.0077 - model_1_loss: 1.3442 - model_1_1_loss: 4.1135 - model_1_2_loss: 8.4989 - model_1_3_loss: 0.0510 - model_1_accuracy: 0.7912 - model_1_1_accuracy: 0.6994 - model_1_2_accuracy: 0.6105 - model_1_3_accuracy: 0.5934
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.6942 - model_1_loss: 1.3430 - model_1_1_loss: 4.0412 - model_1_2_loss: 8.2610 - model_1_3_loss: 0.0490 - model_1_accuracy: 0.7918 - model_1_1_accuracy: 0.7032 - model_1_2_accuracy: 0.6147 - model_1_3_accuracy: 0.5980
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 13.3407 - model_1_loss: 1.3280 - model_1_1_loss: 3.9527 - model_1_2_loss: 8.0131 - model_1_3_loss: 0.0469 - model_1_accuracy: 0.7936 - model_1_1_accuracy: 0.7082 - model_1_2_accuracy: 0.6291 - model_1_3_accuracy: 0.6019
#
# --------------------Mini Batch No. 1492/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4339 - model_1_loss: 0.6183 - model_1_1_loss: 1.6660 - model_1_2_loss: 3.1329 - model_1_3_loss: 0.0165 - model_1_accuracy: 0.8435 - model_1_1_accuracy: 0.7943 - model_1_2_accuracy: 0.7684 - model_1_3_accuracy: 0.7870
# Epoch 2/5
# 1/1 [==============================] - 0s 1ms/step - loss: 5.3034 - model_1_loss: 0.6079 - model_1_1_loss: 1.6223 - model_1_2_loss: 3.0572 - model_1_3_loss: 0.0159 - model_1_accuracy: 0.8450 - model_1_1_accuracy: 0.7948 - model_1_2_accuracy: 0.7683 - model_1_3_accuracy: 0.7924
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 5.1353 - model_1_loss: 0.5973 - model_1_1_loss: 1.5673 - model_1_2_loss: 2.9554 - model_1_3_loss: 0.0152 - model_1_accuracy: 0.8463 - model_1_1_accuracy: 0.7986 - model_1_2_accuracy: 0.7697 - model_1_3_accuracy: 0.8009
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9575 - model_1_loss: 0.5883 - model_1_1_loss: 1.5124 - model_1_2_loss: 2.8423 - model_1_3_loss: 0.0144 - model_1_accuracy: 0.8478 - model_1_1_accuracy: 0.8016 - model_1_2_accuracy: 0.7734 - model_1_3_accuracy: 0.8102
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7911 - model_1_loss: 0.5804 - model_1_1_loss: 1.4651 - model_1_2_loss: 2.7318 - model_1_3_loss: 0.0136 - model_1_accuracy: 0.8480 - model_1_1_accuracy: 0.8036 - model_1_2_accuracy: 0.7741 - model_1_3_accuracy: 0.8133
#
# --------------------Mini Batch No. 1493/1845-------------------
#
# Epoch 1/5
# ...
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.7385 - model_1_loss: 1.3973 - model_1_1_loss: 4.0107 - model_1_2_loss: 7.2930 - model_1_3_loss: 0.0375 - model_1_accuracy: 0.7738 - model_1_1_accuracy: 0.6996 - model_1_2_accuracy: 0.6536 - model_1_3_accuracy: 0.6242
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.4614 - model_1_loss: 1.3752 - model_1_1_loss: 3.9299 - model_1_2_loss: 7.1194 - model_1_3_loss: 0.0368 - model_1_accuracy: 0.7757 - model_1_1_accuracy: 0.7015 - model_1_2_accuracy: 0.6587 - model_1_3_accuracy: 0.6211
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1922 - model_1_loss: 1.3516 - model_1_1_loss: 3.8480 - model_1_2_loss: 6.9564 - model_1_3_loss: 0.0362 - model_1_accuracy: 0.7765 - model_1_1_accuracy: 0.7017 - model_1_2_accuracy: 0.6636 - model_1_3_accuracy: 0.6211
#
# --------------------Mini Batch No. 1836/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.2352 - model_1_loss: 1.1686 - model_1_1_loss: 3.6757 - model_1_2_loss: 7.3502 - model_1_3_loss: 0.0407 - model_1_accuracy: 0.8199 - model_1_1_accuracy: 0.7306 - model_1_2_accuracy: 0.6532 - model_1_3_accuracy: 0.6381
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.2014 - model_1_loss: 1.1641 - model_1_1_loss: 3.6652 - model_1_2_loss: 7.3315 - model_1_3_loss: 0.0406 - model_1_accuracy: 0.8196 - model_1_1_accuracy: 0.7292 - model_1_2_accuracy: 0.6549 - model_1_3_accuracy: 0.6343
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1334 - model_1_loss: 1.1618 - model_1_1_loss: 3.6514 - model_1_2_loss: 7.2800 - model_1_3_loss: 0.0402 - model_1_accuracy: 0.8201 - model_1_1_accuracy: 0.7301 - model_1_2_accuracy: 0.6512 - model_1_3_accuracy: 0.6343
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.9648 - model_1_loss: 1.1569 - model_1_1_loss: 3.6068 - model_1_2_loss: 7.1616 - model_1_3_loss: 0.0395 - model_1_accuracy: 0.8204 - model_1_1_accuracy: 0.7329 - model_1_2_accuracy: 0.6556 - model_1_3_accuracy: 0.6381
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.7005 - model_1_loss: 1.1499 - model_1_1_loss: 3.5331 - model_1_2_loss: 6.9788 - model_1_3_loss: 0.0386 - model_1_accuracy: 0.8217 - model_1_1_accuracy: 0.7387 - model_1_2_accuracy: 0.6653 - model_1_3_accuracy: 0.6466
#
# --------------------Mini Batch No. 1837/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 11.2442 - model_1_loss: 1.0391 - model_1_1_loss: 3.3894 - model_1_2_loss: 6.7850 - model_1_3_loss: 0.0307 - model_1_accuracy: 0.8066 - model_1_1_accuracy: 0.7108 - model_1_2_accuracy: 0.6910 - model_1_3_accuracy: 0.6590
# Epoch 2/5
# 1/1 [==============================] - 0s 3ms/step - loss: 11.0047 - model_1_loss: 1.0312 - model_1_1_loss: 3.3279 - model_1_2_loss: 6.6154 - model_1_3_loss: 0.0302 - model_1_accuracy: 0.8077 - model_1_1_accuracy: 0.7106 - model_1_2_accuracy: 0.6921 - model_1_3_accuracy: 0.6644
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.6833 - model_1_loss: 1.0128 - model_1_1_loss: 3.2441 - model_1_2_loss: 6.3970 - model_1_3_loss: 0.0293 - model_1_accuracy: 0.8101 - model_1_1_accuracy: 0.7140 - model_1_2_accuracy: 0.6959 - model_1_3_accuracy: 0.6690
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.3313 - model_1_loss: 0.9891 - model_1_1_loss: 3.1513 - model_1_2_loss: 6.1625 - model_1_3_loss: 0.0283 - model_1_accuracy: 0.8123 - model_1_1_accuracy: 0.7185 - model_1_2_accuracy: 0.7005 - model_1_3_accuracy: 0.6728
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 10.0168 - model_1_loss: 0.9679 - model_1_1_loss: 3.0736 - model_1_2_loss: 5.9479 - model_1_3_loss: 0.0273 - model_1_accuracy: 0.8147 - model_1_1_accuracy: 0.7270 - model_1_2_accuracy: 0.7043 - model_1_3_accuracy: 0.6775
#
# --------------------Mini Batch No. 1838/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 15.4744 - model_1_loss: 1.2701 - model_1_1_loss: 4.9327 - model_1_2_loss: 9.2212 - model_1_3_loss: 0.0504 - model_1_accuracy: 0.7971 - model_1_1_accuracy: 0.6628 - model_1_2_accuracy: 0.6048 - model_1_3_accuracy: 0.5193
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 15.3955 - model_1_loss: 1.2680 - model_1_1_loss: 4.9118 - model_1_2_loss: 9.1652 - model_1_3_loss: 0.0504 - model_1_accuracy: 0.7970 - model_1_1_accuracy: 0.6620 - model_1_2_accuracy: 0.6056 - model_1_3_accuracy: 0.5139
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 15.1916 - model_1_loss: 1.2675 - model_1_1_loss: 4.8513 - model_1_2_loss: 9.0228 - model_1_3_loss: 0.0499 - model_1_accuracy: 0.7972 - model_1_1_accuracy: 0.6630 - model_1_2_accuracy: 0.6026 - model_1_3_accuracy: 0.5108
# Epoch 4/5
# 1/1 [==============================] - 0s 1ms/step - loss: 14.9572 - model_1_loss: 1.2710 - model_1_1_loss: 4.7851 - model_1_2_loss: 8.8521 - model_1_3_loss: 0.0489 - model_1_accuracy: 0.7972 - model_1_1_accuracy: 0.6643 - model_1_2_accuracy: 0.6017 - model_1_3_accuracy: 0.5108
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 14.7072 - model_1_loss: 1.2782 - model_1_1_loss: 4.7127 - model_1_2_loss: 8.6686 - model_1_3_loss: 0.0476 - model_1_accuracy: 0.7970 - model_1_1_accuracy: 0.6656 - model_1_2_accuracy: 0.6068 - model_1_3_accuracy: 0.5139
#
# --------------------Mini Batch No. 1839/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 6ms/step - loss: 9.1661 - model_1_loss: 0.7765 - model_1_1_loss: 2.6888 - model_1_2_loss: 5.6715 - model_1_3_loss: 0.0292 - model_1_accuracy: 0.8100 - model_1_1_accuracy: 0.7358 - model_1_2_accuracy: 0.6780 - model_1_3_accuracy: 0.6111
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 9.0851 - model_1_loss: 0.7767 - model_1_1_loss: 2.6702 - model_1_2_loss: 5.6091 - model_1_3_loss: 0.0290 - model_1_accuracy: 0.8109 - model_1_1_accuracy: 0.7380 - model_1_2_accuracy: 0.6817 - model_1_3_accuracy: 0.6150
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.9046 - model_1_loss: 0.7665 - model_1_1_loss: 2.6212 - model_1_2_loss: 5.4885 - model_1_3_loss: 0.0284 - model_1_accuracy: 0.8136 - model_1_1_accuracy: 0.7422 - model_1_2_accuracy: 0.6846 - model_1_3_accuracy: 0.6242
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.6791 - model_1_loss: 0.7491 - model_1_1_loss: 2.5554 - model_1_2_loss: 5.3468 - model_1_3_loss: 0.0277 - model_1_accuracy: 0.8185 - model_1_1_accuracy: 0.7461 - model_1_2_accuracy: 0.6941 - model_1_3_accuracy: 0.6304
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 8.4715 - model_1_loss: 0.7308 - model_1_1_loss: 2.4939 - model_1_2_loss: 5.2194 - model_1_3_loss: 0.0272 - model_1_accuracy: 0.8238 - model_1_1_accuracy: 0.7492 - model_1_2_accuracy: 0.6981 - model_1_3_accuracy: 0.6335
#
# --------------------Mini Batch No. 1840/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 18.5904 - model_1_loss: 1.6557 - model_1_1_loss: 5.8016 - model_1_2_loss: 11.0727 - model_1_3_loss: 0.0604 - model_1_accuracy: 0.7609 - model_1_1_accuracy: 0.6620 - model_1_2_accuracy: 0.5606 - model_1_3_accuracy: 0.4985
# Epoch 2/5
# 1/1 [==============================] - 0s 3ms/step - loss: 18.4284 - model_1_loss: 1.6372 - model_1_1_loss: 5.7488 - model_1_2_loss: 10.9821 - model_1_3_loss: 0.0601 - model_1_accuracy: 0.7630 - model_1_1_accuracy: 0.6638 - model_1_2_accuracy: 0.5634 - model_1_3_accuracy: 0.4985
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 18.2180 - model_1_loss: 1.6228 - model_1_1_loss: 5.6849 - model_1_2_loss: 10.8509 - model_1_3_loss: 0.0594 - model_1_accuracy: 0.7645 - model_1_1_accuracy: 0.6644 - model_1_2_accuracy: 0.5721 - model_1_3_accuracy: 0.5062
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 17.9590 - model_1_loss: 1.6158 - model_1_1_loss: 5.6117 - model_1_2_loss: 10.6732 - model_1_3_loss: 0.0582 - model_1_accuracy: 0.7661 - model_1_1_accuracy: 0.6652 - model_1_2_accuracy: 0.5838 - model_1_3_accuracy: 0.5077
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 17.6796 - model_1_loss: 1.6134 - model_1_1_loss: 5.5338 - model_1_2_loss: 10.4753 - model_1_3_loss: 0.0570 - model_1_accuracy: 0.7676 - model_1_1_accuracy: 0.6669 - model_1_2_accuracy: 0.5880 - model_1_3_accuracy: 0.5123
#
# --------------------Mini Batch No. 1841/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 2ms/step - loss: 16.8101 - model_1_loss: 1.4676 - model_1_1_loss: 5.1156 - model_1_2_loss: 10.1725 - model_1_3_loss: 0.0543 - model_1_accuracy: 0.7508 - model_1_1_accuracy: 0.6378 - model_1_2_accuracy: 0.5814 - model_1_3_accuracy: 0.5332
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 16.3836 - model_1_loss: 1.4564 - model_1_1_loss: 5.0029 - model_1_2_loss: 9.8720 - model_1_3_loss: 0.0522 - model_1_accuracy: 0.7519 - model_1_1_accuracy: 0.6396 - model_1_2_accuracy: 0.5824 - model_1_3_accuracy: 0.5463
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 16.0411 - model_1_loss: 1.4535 - model_1_1_loss: 4.9192 - model_1_2_loss: 9.6180 - model_1_3_loss: 0.0503 - model_1_accuracy: 0.7522 - model_1_1_accuracy: 0.6405 - model_1_2_accuracy: 0.5930 - model_1_3_accuracy: 0.5548
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 15.7980 - model_1_loss: 1.4585 - model_1_1_loss: 4.8739 - model_1_2_loss: 9.4169 - model_1_3_loss: 0.0486 - model_1_accuracy: 0.7504 - model_1_1_accuracy: 0.6422 - model_1_2_accuracy: 0.5933 - model_1_3_accuracy: 0.5556
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 15.5229 - model_1_loss: 1.4586 - model_1_1_loss: 4.8218 - model_1_2_loss: 9.1952 - model_1_3_loss: 0.0473 - model_1_accuracy: 0.7499 - model_1_1_accuracy: 0.6439 - model_1_2_accuracy: 0.5951 - model_1_3_accuracy: 0.5633
#
# --------------------Mini Batch No. 1842/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 4.9102 - model_1_loss: 0.5234 - model_1_1_loss: 1.4990 - model_1_2_loss: 2.8727 - model_1_3_loss: 0.0150 - model_1_accuracy: 0.8582 - model_1_1_accuracy: 0.8017 - model_1_2_accuracy: 0.7794 - model_1_3_accuracy: 0.7600
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.7840 - model_1_loss: 0.5147 - model_1_1_loss: 1.4617 - model_1_2_loss: 2.7929 - model_1_3_loss: 0.0145 - model_1_accuracy: 0.8590 - model_1_1_accuracy: 0.8050 - model_1_2_accuracy: 0.7860 - model_1_3_accuracy: 0.7654
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 4.6926 - model_1_loss: 0.5076 - model_1_1_loss: 1.4370 - model_1_2_loss: 2.7337 - model_1_3_loss: 0.0142 - model_1_accuracy: 0.8597 - model_1_1_accuracy: 0.8046 - model_1_2_accuracy: 0.7874 - model_1_3_accuracy: 0.7685
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.6420 - model_1_loss: 0.5055 - model_1_1_loss: 1.4249 - model_1_2_loss: 2.6974 - model_1_3_loss: 0.0140 - model_1_accuracy: 0.8599 - model_1_1_accuracy: 0.8047 - model_1_2_accuracy: 0.7867 - model_1_3_accuracy: 0.7778
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 4.5673 - model_1_loss: 0.5033 - model_1_1_loss: 1.4041 - model_1_2_loss: 2.6460 - model_1_3_loss: 0.0138 - model_1_accuracy: 0.8611 - model_1_1_accuracy: 0.8058 - model_1_2_accuracy: 0.7854 - model_1_3_accuracy: 0.7770
#
# --------------------Mini Batch No. 1843/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 7.2645 - model_1_loss: 0.8172 - model_1_1_loss: 2.2449 - model_1_2_loss: 4.1802 - model_1_3_loss: 0.0222 - model_1_accuracy: 0.8189 - model_1_1_accuracy: 0.7478 - model_1_2_accuracy: 0.7385 - model_1_3_accuracy: 0.7238
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0742 - model_1_loss: 0.8018 - model_1_1_loss: 2.1917 - model_1_2_loss: 4.0592 - model_1_3_loss: 0.0214 - model_1_accuracy: 0.8217 - model_1_1_accuracy: 0.7525 - model_1_2_accuracy: 0.7445 - model_1_3_accuracy: 0.7261
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9119 - model_1_loss: 0.7902 - model_1_1_loss: 2.1535 - model_1_2_loss: 3.9477 - model_1_3_loss: 0.0205 - model_1_accuracy: 0.8246 - model_1_1_accuracy: 0.7548 - model_1_2_accuracy: 0.7511 - model_1_3_accuracy: 0.7377
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8615 - model_1_loss: 0.7889 - model_1_1_loss: 2.1511 - model_1_2_loss: 3.9014 - model_1_3_loss: 0.0199 - model_1_accuracy: 0.8254 - model_1_1_accuracy: 0.7591 - model_1_2_accuracy: 0.7533 - model_1_3_accuracy: 0.7454
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 6.8484 - model_1_loss: 0.7910 - model_1_1_loss: 2.1557 - model_1_2_loss: 3.8820 - model_1_3_loss: 0.0197 - model_1_accuracy: 0.8254 - model_1_1_accuracy: 0.7587 - model_1_2_accuracy: 0.7588 - model_1_3_accuracy: 0.7431
#
# --------------------Mini Batch No. 1844/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 12.7372 - model_1_loss: 1.2944 - model_1_1_loss: 3.9925 - model_1_2_loss: 7.4067 - model_1_3_loss: 0.0435 - model_1_accuracy: 0.7640 - model_1_1_accuracy: 0.6809 - model_1_2_accuracy: 0.6728 - model_1_3_accuracy: 0.5941
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.5807 - model_1_loss: 1.2871 - model_1_1_loss: 3.9436 - model_1_2_loss: 7.3068 - model_1_3_loss: 0.0430 - model_1_accuracy: 0.7643 - model_1_1_accuracy: 0.6839 - model_1_2_accuracy: 0.6760 - model_1_3_accuracy: 0.5934
# Epoch 3/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.3548 - model_1_loss: 1.2795 - model_1_1_loss: 3.8764 - model_1_2_loss: 7.1564 - model_1_3_loss: 0.0423 - model_1_accuracy: 0.7663 - model_1_1_accuracy: 0.6866 - model_1_2_accuracy: 0.6790 - model_1_3_accuracy: 0.5972
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 12.1492 - model_1_loss: 1.2760 - model_1_1_loss: 3.8209 - model_1_2_loss: 7.0107 - model_1_3_loss: 0.0415 - model_1_accuracy: 0.7668 - model_1_1_accuracy: 0.6875 - model_1_2_accuracy: 0.6846 - model_1_3_accuracy: 0.6088
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 11.9499 - model_1_loss: 1.2753 - model_1_1_loss: 3.7703 - model_1_2_loss: 6.8635 - model_1_3_loss: 0.0407 - model_1_accuracy: 0.7665 - model_1_1_accuracy: 0.6900 - model_1_2_accuracy: 0.6857 - model_1_3_accuracy: 0.6119
#
# --------------------Mini Batch No. 1845/1845-------------------
#
# Epoch 1/5
# 1/1 [==============================] - 0s 1ms/step - loss: 23.2123 - model_1_loss: 2.0390 - model_1_1_loss: 6.8003 - model_1_2_loss: 14.2922 - model_1_3_loss: 0.0808 - model_1_accuracy: 0.7087 - model_1_1_accuracy: 0.5967 - model_1_2_accuracy: 0.5387 - model_1_3_accuracy: 0.4707
# Epoch 2/5
# 1/1 [==============================] - 0s 2ms/step - loss: 22.7383 - model_1_loss: 2.0452 - model_1_1_loss: 6.6844 - model_1_2_loss: 13.9294 - model_1_3_loss: 0.0793 - model_1_accuracy: 0.7079 - model_1_1_accuracy: 0.5987 - model_1_2_accuracy: 0.5480 - model_1_3_accuracy: 0.4699
# Epoch 3/5
# 1/1 [==============================] - 0s 1ms/step - loss: 22.2706 - model_1_loss: 2.0593 - model_1_1_loss: 6.5621 - model_1_2_loss: 13.5714 - model_1_3_loss: 0.0777 - model_1_accuracy: 0.7056 - model_1_1_accuracy: 0.6002 - model_1_2_accuracy: 0.5522 - model_1_3_accuracy: 0.4769
# Epoch 4/5
# 1/1 [==============================] - 0s 2ms/step - loss: 21.9157 - model_1_loss: 2.0719 - model_1_1_loss: 6.4626 - model_1_2_loss: 13.3049 - model_1_3_loss: 0.0763 - model_1_accuracy: 0.7035 - model_1_1_accuracy: 0.6019 - model_1_2_accuracy: 0.5541 - model_1_3_accuracy: 0.4907
# Epoch 5/5
# 1/1 [==============================] - 0s 2ms/step - loss: 21.5681 - model_1_loss: 2.0641 - model_1_1_loss: 6.3523 - model_1_2_loss: 13.0765 - model_1_3_loss: 0.0751 - model_1_accuracy: 0.7028 - model_1_1_accuracy: 0.6041 - model_1_2_accuracy: 0.5601 - model_1_3_accuracy: 0.4938
# Saved model to disk

# %%
saving_model(epo=0,model_save=True)
# Out:
# Saved model to disk

# %%
autoencoder.load_weights(os.getcwd() +'/autoencoder_model_weights_0.h5')

# %%
test_image = skimage.transform.resize(test_image,(target_height,target_width))
test_image = np.array(test_image)
test_image = np.expand_dims(test_image,axis=0)

test_result = autoencoder.predict(test_image)

# %%
'''
actual_image = plt.imread('Golu.jpg')

test_image = rescaling_images(actual_image,scaling_factor=0.1)
test_image = skimage.transform.resize(test_image,(target_height,target_width))


test_image = np.array(test_image)
test_image = np.expand_dims(test_image, axis=0)

actual_image = skimage.transform.resize(actual_image,(target_height,target_width))


test_result = autoencoder.predict(test_image)

print(test_result.shape)
'''
# Out:
# "\nactual_image = plt.imread('Golu.jpg')\n\ntest_image = rescaling_images(actual_image,scaling_factor=0.1)\ntest_image = skimage.transform.resize(test_image,(target_height,target_width))\n\n\ntest_image = np.array(test_image)\ntest_image = np.expand_dims(test_image, axis=0)\n\nactual_image = skimage.transform.resize(actual_image,(target_height,target_width))\n\n\ntest_result = autoencoder.predict(test_image)\n\nprint(test_result.shape)\n"

# %%
test_result = np.squeeze(test_result,axis=0)
plt.imshow(test_result)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.figure(figsize=(80,80) )

ax = plt.subplot(10, 10, 1)
plt.imshow(np.squeeze(test_image,axis=0))
plt.axis('off')

ax = plt.subplot(10, 10, 2)
plt.imshow(np.squeeze(test_image,axis=0), interpolation="bicubic")
plt.axis('off')

ax = plt.subplot(10, 10, 3)
plt.imshow(test_result)
plt.axis('off')

ax = plt.subplot(10, 10, 4)
actual_image = skimage.transform.resize(actual_image,(target_height,target_width))
plt.axis('off')

plt.imshow(actual_image)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
